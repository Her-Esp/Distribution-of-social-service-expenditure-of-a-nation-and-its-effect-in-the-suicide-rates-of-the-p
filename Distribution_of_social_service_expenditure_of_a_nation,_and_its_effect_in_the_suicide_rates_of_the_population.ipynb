# %%
pip install linearmodels
# Out:
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed linearmodels-4.24 mypy-extensions-0.4.3 property-cached-1.6.4 pyhdfe-0.1.0 statsmodels-0.12.2

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
from linearmodels import PooledOLS
from statsmodels.stats.stattools import durbin_watson
from statsmodels.stats.diagnostic import het_white, het_breuschpagan
from linearmodels import PanelOLS
from linearmodels import RandomEffects
import numpy.linalg as la
from scipy import stats
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
def hausman(fe, re):
  b = fe.params
  B = re.params
  v_b = fe.cov
  v_B = re.cov
  df = b[np.abs(b) < 1e8].size
  chi2 = np.dot((b - B).T, la.inv(v_b - v_B).dot(b - B)) 
  pval = stats.chi2.sf(chi2, df)
  return chi2, df, pval

# %%
df = pd.read_csv("Dataset.csv", index_col = ['Location','Period'])
years = df.index.get_level_values('Period').to_list()
df['Period'] = pd.Categorical(years)
df.head()
# Out:
#                   Suicide_per_100000  Male  Female  ...  Other     Total_GDP  Period
# Location  Period                                    ...
# Australia 2000                  12.7  19.9     5.6  ...  0.159  8.491370e+11    2000
# Austria   2000                  19.9  29.8    10.6  ...  0.292  3.364950e+11    2000
# Belgium   2000                  22.0  31.5    12.9  ...  0.688  4.058330e+11    2000
# Canada    2000                  11.9  18.3     5.7  ...  2.405  1.207140e+12    2000
# Chile     2000                  10.3  17.9     2.9  ...  0.244  4.871490e+11    2000
#
# [5 rows x 15 columns]

# %%
df_t = df.copy()
var_name = ['PSEGDP','Old_Age','Survivors','Incapacity','Family','Labour',"Unemployment",'Housing','Health','Other']
dvar_name = ['Suicide_per_100000', 'Male', 'Female']
for i in var_name:
  df_t[i] = df_t[i]*df_t['Total_GDP']/100000000
df_t.head()
# Out:
#                   Suicide_per_100000  Male  ...     Total_GDP  Period
# Location  Period                            ...
# Australia 2000                  12.7  19.9  ...  8.491370e+11    2000
# Austria   2000                  19.9  29.8  ...  3.364950e+11    2000
# Belgium   2000                  22.0  31.5  ...  4.058330e+11    2000
# Canada    2000                  11.9  18.3  ...  1.207140e+12    2000
# Chile     2000                  10.3  17.9  ...  4.871490e+11    2000
#
# [5 rows x 15 columns]

# %%
results_all_var = pd.DataFrame(columns = ['Dependent', 'White Test P-Value', 'Breusch Pagan Test P-Value',
                                  'Durbin Watson Test P-Value','Hausman Entity vs Random', 'Hausman Time vs Random',
                                   'Hausman Entity and Time vs Random'])
for i in dvar_name:
  exog = sm.tools.tools.add_constant(df[['PSEGDP','Old_Age','Survivors','Incapacity','Family','Labour',"Unemployment",'Housing','Health','Other']])
  endog = df[i]
  mod = PooledOLS(endog, exog)
  pooledOLS_res = mod.fit(cov_type='clustered', cluster_entity=True)
  # Store values for checking homoskedasticity graphically
  fittedvals_pooled_OLS = pooledOLS_res.predict().fitted_values
  residuals_pooled_OLS = pooledOLS_res.resids
  fig, ax = plt.subplots()
  ax.scatter(fittedvals_pooled_OLS, residuals_pooled_OLS,s = 0.5, color = 'blue')
  ax.axhline(0, color = 'r', ls = '--')
  ax.set_xlabel('Predicted Values', fontsize = 15)
  ax.set_ylabel('Residuals', fontsize = 15)
  ax.set_title('Homoskedasticity Test', fontsize = 30)
  plt.close(fig)
  plt.savefig('All_Var_'+i+'.png')

  pooled_OLS_dataset = pd.concat([df, residuals_pooled_OLS], axis=1)
  pooled_OLS_dataset = pooled_OLS_dataset.drop(['Period'], axis = 1).fillna(0)
  exog = sm.tools.tools.add_constant(df[i]).fillna(0)
  white_test_results = het_white(pooled_OLS_dataset['residual'], exog)

  # 3A.3 Breusch-Pagan-Test
  breusch_pagan_test_results = het_breuschpagan(pooled_OLS_dataset['residual'], exog)
  durbin_watson_test_results = durbin_watson(pooled_OLS_dataset['residual']) 

  exog = sm.tools.tools.add_constant(df[['PSEGDP','Old_Age','Survivors','Incapacity','Family','Labour',"Unemployment",'Housing','Health','Other']])
  endog = df[i]
  model_re = RandomEffects(endog, exog) 
  re_res = model_re.fit() 
  print(re_res)
  # fixed effects model
  model_fe = PanelOLS(endog, exog, entity_effects = True) 
  fe_res = model_fe.fit() 
  print(fe_res)
  # time effects
  model_te = PanelOLS(endog, exog, time_effects = True)
  te_res =  model_te.fit() 
  print(te_res)
  # time effects
  model_te_fe = PanelOLS(endog, exog, entity_effects = True, time_effects = True)
  fe_te_res =  model_te_fe.fit() 
  print(fe_te_res)

  hausman_results1 = hausman(fe_res, re_res) 
  hausman_results2 = hausman(te_res, re_res) 
  hausman_results3 = hausman(fe_te_res, re_res)

  results_all_var = results_all_var.append({'Dependent' : i, 'White Test P-Value' : white_test_results[1], 'Breusch Pagan Test P-Value' : breusch_pagan_test_results[1],
                              'Durbin Watson Test P-Value' : durbin_watson_test_results,
                              'Hausman Entity vs Random' : hausman_results1[2], 'Hausman Time vs Random' : hausman_results2[2],
                              'Hausman Entity and Time vs Random' : hausman_results3[2]}, ignore_index = True)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:     Suicide_per_100000   R-squared:                        0.0934
# Estimator:              RandomEffects   R-squared (Between):             -0.0698
# No. Observations:                 630   R-squared (Within):               0.1014
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.0551
# Time:                        20:38:40   Log-likelihood                   -1394.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.3799
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,619)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             6.3799
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,619)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            18.145     1.7038     10.650     0.0000      14.799      21.491
# PSEGDP          -0.4910     0.4582    -1.0715     0.2844     -1.3908      0.4089
# Old_Age          0.2981     0.4808     0.6199     0.5355     -0.6461      1.2422
# Survivors        0.8158     0.7466     1.0928     0.2749     -0.6503      2.2820
# Incapacity       1.2520     0.6298     1.9879     0.0473      0.0152      2.4889
# Family          -0.3145     0.5867    -0.5361     0.5921     -1.4668      0.8377
# Labour          -4.6637     0.9349    -4.9883     0.0000     -6.4997     -2.8277
# Unemployment     1.9428     0.6501     2.9883     0.0029      0.6660      3.2195
# Housing         -1.0071     1.1798    -0.8536     0.3936     -3.3240      1.3098
# Health           0.3372     0.4981     0.6770     0.4987     -0.6409      1.3154
# Other            1.2599     0.7962     1.5823     0.1141     -0.3038      2.8235
# ================================================================================
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:     Suicide_per_100000   R-squared:                        0.1024
# Estimator:                   PanelOLS   R-squared (Between):             -0.1142
# No. Observations:                 630   R-squared (Within):               0.1024
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.0956
# Time:                        20:38:41   Log-likelihood                   -1376.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.6744
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,585)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             6.6744
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,585)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            18.379     1.1167     16.459     0.0000      16.185      20.572
# PSEGDP          -0.2751     0.4743    -0.5800     0.5621     -1.2067      0.6565
# Old_Age          0.0466     0.4982     0.0935     0.9255     -0.9318      1.0250
# Survivors        0.7365     0.7819     0.9420     0.3466     -0.7991      2.2721
# Incapacity       0.9098     0.6488     1.4022     0.1614     -0.3645      2.1840
# Family          -0.6117     0.6032    -1.0141     0.3110     -1.7963      0.5730
# Labour          -5.1855     0.9728    -5.3306     0.0000     -7.0961     -3.2749
# Unemployment     1.7486     0.6733     2.5970     0.0096      0.4262      3.0711
# Housing         -1.2975     1.2134    -1.0693     0.2854     -3.6807      1.0857
# Health           0.1746     0.5137     0.3399     0.7341     -0.8344      1.1836
# Other            1.1330     0.8151     1.3900     0.1650     -0.4679      2.7339
# ================================================================================
#
# F-test for Poolability: 163.64
# P-value: 0.0000
# Distribution: F(34,585)
#
# Included effects: Entity
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:     Suicide_per_100000   R-squared:                        0.2095
# Estimator:                   PanelOLS   R-squared (Between):              0.2388
# No. Observations:                 630   R-squared (Within):              -0.3849
# Date:                Tue, Jun 01 2021   R-squared (Overall):              0.1852
# Time:                        20:38:41   Log-likelihood                   -2106.0
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      15.955
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,602)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             15.955
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,602)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            15.992     1.1682     13.689     0.0000      13.698      18.286
# PSEGDP          -2.2123     0.4718    -4.6889     0.0000     -3.1389     -1.2857
# Old_Age          3.4880     0.4666     7.4758     0.0000      2.5717      4.4043
# Survivors       -2.5630     0.8222    -3.1173     0.0019     -4.1777     -0.9483
# Incapacity       1.9423     0.8062     2.4093     0.0163      0.3591      3.5255
# Family           2.7079     0.6690     4.0478     0.0001      1.3941      4.0218
# Labour          -0.5884     0.9759    -0.6029     0.5468     -2.5051      1.3282
# Unemployment     4.8061     0.6151     7.8136     0.0000      3.5981      6.0141
# Housing         -1.2401     1.3963    -0.8881     0.3748     -3.9822      1.5021
# Health           1.4793     0.5952     2.4853     0.0132      0.3103      2.6483
# Other            1.7425     0.8835     1.9723     0.0490      0.0074      3.4776
# ================================================================================
#
# F-test for Poolability: 1.3472
# P-value: 0.1574
# Distribution: F(17,602)
#
# Included effects: Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:     Suicide_per_100000   R-squared:                        0.1292
# Estimator:                   PanelOLS   R-squared (Between):             -0.0498
# No. Observations:                 630   R-squared (Within):              -0.0308
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.0481
# Time:                        20:38:41   Log-likelihood                   -1317.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      8.4310
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,568)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             8.4310
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,568)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            13.867     1.2685     10.933     0.0000      11.376      16.359
# PSEGDP          -0.9586     0.4519    -2.1212     0.0343     -1.8463     -0.0710
# Old_Age          1.3624     0.4839     2.8158     0.0050      0.4121      2.3128
# Survivors        0.5931     0.7343     0.8077     0.4196     -0.8492      2.0353
# Incapacity       0.5501     0.6175     0.8909     0.3734     -0.6627      1.7628
# Family           0.7855     0.5802     1.3537     0.1764     -0.3542      1.9251
# Labour          -5.6986     0.9070    -6.2830     0.0000     -7.4801     -3.9172
# Unemployment     1.6117     0.6245     2.5807     0.0101      0.3851      2.8384
# Housing          1.0670     1.1559     0.9231     0.3564     -1.2034      3.3374
# Health           1.3259     0.4911     2.6997     0.0071      0.3612      2.2905
# Other            2.1960     0.7677     2.8607     0.0044      0.6882      3.7038
# ================================================================================
#
# F-test for Poolability: 130.03
# P-value: 0.0000
# Distribution: F(51,568)
#
# Included effects: Entity, Time
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                   Male   R-squared:                        0.0987
# Estimator:              RandomEffects   R-squared (Between):             -0.0633
# No. Observations:                 630   R-squared (Within):               0.1067
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.0505
# Time:                        20:38:41   Log-likelihood                   -1680.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      6.7798
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,619)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             6.7798
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,619)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            28.055     2.7906     10.053     0.0000      22.574      33.535
# PSEGDP          -0.7549     0.7238    -1.0430     0.2974     -2.1764      0.6665
# Old_Age          0.4544     0.7596     0.5982     0.5499     -1.0372      1.9460
# Survivors        1.7875     1.1808     1.5138     0.1306     -0.5313      4.1064
# Incapacity       1.9465     0.9944     1.9575     0.0507     -0.0063      3.8992
# Family          -0.7650     0.9262    -0.8260     0.4091     -2.5838      1.0538
# Labour          -7.3715     1.4778    -4.9883     0.0000     -10.274     -4.4695
# Unemployment     3.1874     1.0271     3.1034     0.0020      1.1704      5.2044
# Housing         -1.7674     1.8623    -0.9490     0.3430     -5.4246      1.8899
# Health           0.5302     0.7865     0.6742     0.5005     -1.0143      2.0747
# Other            2.0369     1.2563     1.6213     0.1055     -0.4303      4.5040
# ================================================================================
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   Male   R-squared:                        0.1076
# Estimator:                   PanelOLS   R-squared (Between):             -0.1002
# No. Observations:                 630   R-squared (Within):               0.1076
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.0846
# Time:                        20:38:41   Log-likelihood                   -1662.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      7.0533
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,585)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             7.0533
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,585)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            28.265     1.7564     16.093     0.0000      24.816      31.715
# PSEGDP          -0.4318     0.7461    -0.5788     0.5629     -1.8971      1.0334
# Old_Age          0.0761     0.7836     0.0972     0.9226     -1.4628      1.6151
# Survivors        1.7021     1.2298     1.3841     0.1669     -0.7132      4.1175
# Incapacity       1.4510     1.0205     1.4218     0.1556     -0.5533      3.4554
# Family          -1.2219     0.9488    -1.2879     0.1983     -3.0853      0.6415
# Labour          -8.0688     1.5301    -5.2733     0.0000     -11.074     -5.0636
# Unemployment     2.9187     1.0591     2.7558     0.0060      0.8386      4.9989
# Housing         -2.1842     1.9086    -1.1444     0.2529     -5.9328      1.5644
# Health           0.2940     0.8081     0.3638     0.7161     -1.2931      1.8811
# Other            1.8934     1.2821     1.4768     0.1403     -0.6246      4.4115
# ================================================================================
#
# F-test for Poolability: 186.23
# P-value: 0.0000
# Distribution: F(34,585)
#
# Included effects: Entity
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   Male   R-squared:                        0.2249
# Estimator:                   PanelOLS   R-squared (Between):              0.2547
# No. Observations:                 630   R-squared (Within):              -0.4594
# Date:                Tue, Jun 01 2021   R-squared (Overall):              0.2009
# Time:                        20:38:41   Log-likelihood                   -2428.3
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      17.467
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,602)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             17.467
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,602)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            26.831     1.9483     13.771     0.0000      23.005      30.658
# PSEGDP          -4.2550     0.7869    -5.4072     0.0000     -5.8004     -2.7095
# Old_Age          6.4940     0.7782     8.3452     0.0000      4.9657      8.0223
# Survivors       -3.7228     1.3713    -2.7149     0.0068     -6.4159     -1.0298
# Incapacity       3.5589     1.3446     2.6469     0.0083      0.9183      6.1995
# Family           5.1840     1.1158     4.6461     0.0000      2.9927      7.3753
# Labour          -1.1096     1.6277    -0.6817     0.4957     -4.3063      2.0870
# Unemployment     7.8500     1.0259     7.6520     0.0000      5.8353      9.8648
# Housing         -1.4897     2.3287    -0.6397     0.5226     -6.0631      3.0837
# Health           2.8747     0.9928     2.8957     0.0039      0.9250      4.8244
# Other            2.3501     1.4735     1.5949     0.1113     -0.5437      5.2440
# ================================================================================
#
# F-test for Poolability: 1.3662
# P-value: 0.1469
# Distribution: F(17,602)
#
# Included effects: Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   Male   R-squared:                        0.1379
# Estimator:                   PanelOLS   R-squared (Between):             -0.0417
# No. Observations:                 630   R-squared (Within):              -0.0324
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.0410
# Time:                        20:38:42   Log-likelihood                   -1594.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      9.0856
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,568)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             9.0856
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,568)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            21.222     1.9671     10.788     0.0000      17.358      25.086
# PSEGDP          -1.5976     0.7009    -2.2795     0.0230     -2.9742     -0.2210
# Old_Age          2.2599     0.7503     3.0118     0.0027      0.7861      3.7337
# Survivors        1.5230     1.1387     1.3375     0.1816     -0.7136      3.7596
# Incapacity       0.8872     0.9575     0.9266     0.3545     -0.9935      2.7680
# Family           1.0894     0.8998     1.2107     0.2265     -0.6780      2.8568
# Labour          -9.0047     1.4066    -6.4019     0.0000     -11.767     -6.2420
# Unemployment     2.7065     0.9685     2.7946     0.0054      0.8043      4.6088
# Housing          1.7355     1.7926     0.9681     0.3334     -1.7854      5.2564
# Health           2.2236     0.7616     2.9195     0.0036      0.7276      3.7195
# Other            3.6140     1.1905     3.0358     0.0025      1.2758      5.9523
# ================================================================================
#
# F-test for Poolability: 152.23
# P-value: 0.0000
# Distribution: F(51,568)
#
# Included effects: Entity, Time
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 Female   R-squared:                        0.0586
# Estimator:              RandomEffects   R-squared (Between):             -0.0649
# No. Observations:                 630   R-squared (Within):               0.0646
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.0495
# Time:                        20:38:42   Log-likelihood                   -1067.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      3.8564
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,619)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             3.8564
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,619)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            8.8825     0.9136     9.7227     0.0000      7.0884      10.677
# PSEGDP          -0.2790     0.2689    -1.0375     0.2999     -0.8071      0.2491
# Old_Age          0.2015     0.2820     0.7144     0.4752     -0.3524      0.7554
# Survivors       -0.0364     0.4365    -0.0835     0.9335     -0.8935      0.8207
# Incapacity       0.6459     0.3703     1.7442     0.0816     -0.0813      1.3732
# Family           0.0941     0.3452     0.2727     0.7852     -0.5838      0.7721
# Labour          -2.1795     0.5476    -3.9802     0.0001     -3.2549     -1.1041
# Unemployment     0.8537     0.3814     2.2381     0.0256      0.1046      1.6028
# Housing         -0.2793     0.6941    -0.4023     0.6876     -1.6423      1.0838
# Health           0.1826     0.2928     0.6237     0.5331     -0.3923      0.7575
# Other            0.5666     0.4692     1.2077     0.2276     -0.3547      1.4880
# ================================================================================
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 Female   R-squared:                        0.0660
# Estimator:                   PanelOLS   R-squared (Between):             -0.1259
# No. Observations:                 630   R-squared (Within):               0.0660
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.1031
# Time:                        20:38:42   Log-likelihood                   -1050.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.1331
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,585)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             4.1331
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,585)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            9.1762     0.6651     13.796     0.0000      7.8699      10.483
# PSEGDP          -0.1662     0.2825    -0.5882     0.5566     -0.7211      0.3887
# Old_Age          0.0708     0.2967     0.2385     0.8116     -0.5120      0.6535
# Survivors       -0.1086     0.4657    -0.2333     0.8156     -1.0233      0.8061
# Incapacity       0.4419     0.3865     1.1434     0.2533     -0.3172      1.2009
# Family          -0.0487     0.3593    -0.1354     0.8923     -0.7543      0.6570
# Labour          -2.5649     0.5794    -4.4265     0.0000     -3.7030     -1.4269
# Unemployment     0.7214     0.4011     1.7987     0.0726     -0.0663      1.5092
# Housing         -0.4397     0.7228    -0.6084     0.5432     -1.8593      0.9799
# Health           0.0921     0.3060     0.3009     0.7636     -0.5089      0.6931
# Other            0.4452     0.4855     0.9170     0.3595     -0.5084      1.3988
# ================================================================================
#
# F-test for Poolability: 113.63
# P-value: 0.0000
# Distribution: F(34,585)
#
# Included effects: Entity
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 Female   R-squared:                        0.1718
# Estimator:                   PanelOLS   R-squared (Between):              0.2037
# No. Observations:                 630   R-squared (Within):              -0.2306
# Date:                Tue, Jun 01 2021   R-squared (Overall):              0.1521
# Time:                        20:38:42   Log-likelihood                   -1680.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      12.491
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,602)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             12.491
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,602)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            6.3505     0.5947     10.679     0.0000      5.1826      7.5185
# PSEGDP          -0.3922     0.2402    -1.6327     0.1031     -0.8639      0.0796
# Old_Age          0.8826     0.2375     3.7157     0.0002      0.4161      1.3490
# Survivors       -1.7634     0.4186    -4.2129     0.0000     -2.5854     -0.9414
# Incapacity       0.3872     0.4104     0.9435     0.3458     -0.4188      1.1932
# Family           0.5477     0.3406     1.6081     0.1083     -0.1212      1.2165
# Labour          -0.0523     0.4968    -0.1053     0.9162     -1.0280      0.9234
# Unemployment     2.1313     0.3131     6.8062     0.0000      1.5163      2.7462
# Housing         -1.2484     0.7108    -1.7563     0.0795     -2.6443      0.1476
# Health           0.1515     0.3030     0.4998     0.6174     -0.4437      0.7466
# Other            1.0251     0.4498     2.2793     0.0230      0.1418      1.9084
# ================================================================================
#
# F-test for Poolability: 0.9984
# P-value: 0.4581
# Distribution: F(17,602)
#
# Included effects: Time
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 Female   R-squared:                        0.0811
# Estimator:                   PanelOLS   R-squared (Between):             -0.0533
# No. Observations:                 630   R-squared (Within):              -0.0204
# Date:                Tue, Jun 01 2021   R-squared (Overall):             -0.0494
# Time:                        20:38:43   Log-likelihood                   -1021.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      5.0160
# Entities:                          35   P-value                           0.0000
# Avg Obs:                       18.000   Distribution:                  F(10,568)
# Min Obs:                       18.000
# Max Obs:                       18.000   F-statistic (robust):             5.0160
#                                         P-value                           0.0000
# Time periods:                      18   Distribution:                  F(10,568)
# Avg Obs:                       35.000
# Min Obs:                       35.000
# Max Obs:                       35.000
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            6.8160     0.7921     8.6045     0.0000      5.2601      8.3719
# PSEGDP          -0.4153     0.2822    -1.4716     0.1417     -0.9697      0.1390
# Old_Age          0.6239     0.3022     2.0647     0.0394      0.0304      1.2174
# Survivors       -0.2471     0.4586    -0.5388     0.5902     -1.1478      0.6536
# Incapacity       0.2476     0.3856     0.6421     0.5210     -0.5098      1.0050
# Family           0.5425     0.3624     1.4972     0.1349     -0.1692      1.2542
# Labour          -2.6919     0.5664    -4.7525     0.0000     -3.8044     -1.5794
# Unemployment     0.6442     0.3900     1.6518     0.0991     -0.1218      1.4103
# Housing          0.5589     0.7219     0.7742     0.4391     -0.8590      1.9767
# Health           0.5459     0.3067     1.7800     0.0756     -0.0565      1.1483
# Other            0.9313     0.4794     1.9426     0.0526     -0.0104      1.8729
# ================================================================================
#
# F-test for Poolability: 81.782
# P-value: 0.0000
# Distribution: F(51,568)
#
# Included effects: Entity, Time

# %%
print(results_all_var)
results_all_var.to_csv('Results_all_var.csv')
# Out:
#             Dependent  ...  Hausman Entity and Time vs Random
# 0  Suicide_per_100000  ...                       2.394768e-24
# 1                Male  ...                       1.000000e+00
# 2              Female  ...                       1.152234e-65
#
# [3 rows x 7 columns]

# %%
results = pd.DataFrame(columns = ['Independent Variable', 'Dependent', 'White Test P-Value', 'Breusch Pagan Test P-Value',
                                  'Durbin Watson Test P-Value', 'Random Effect P-Values','Const R', 'I Var R', 'Fixed Effect P-Values', 'Const FE', 'I Var FE',
                                  'Time Effect P-Values','Const FT', 'I Var FT', 'Entity and Time P-Values','Const FA', 'I Var FA',
                                  'Hausman Entity vs Random', 'Hausman Time vs Random', 'Hausman Entity and Time vs Random',
                                  'Hausman Time vs Entity',
                                  'Hausman Entity and Time vs Entity','Hausman Entity and Time vs Time'])
for i in var_name:
  for j in dvar_name:
    exog = sm.tools.tools.add_constant(df[i])
    endog = df[j]
    mod = PooledOLS(endog, exog)
    pooledOLS_res = mod.fit(cov_type='clustered', cluster_entity=True)
    # Store values for checking homoskedasticity graphically
    fittedvals_pooled_OLS = pooledOLS_res.predict().fitted_values
    residuals_pooled_OLS = pooledOLS_res.resids
    fig, ax = plt.subplots()
    ax.scatter(fittedvals_pooled_OLS, residuals_pooled_OLS,s = 0.5, color = 'blue')
    ax.axhline(0, color = 'r', ls = '--')
    ax.set_xlabel('Predicted Values', fontsize = 15)
    ax.set_ylabel('Residuals', fontsize = 15)
    ax.set_title('Homoskedasticity Test', fontsize = 30)
    plt.close(fig)
    plt.savefig(i+'_'+j+'.png')

    pooled_OLS_dataset = pd.concat([df, residuals_pooled_OLS], axis=1)
    pooled_OLS_dataset = pooled_OLS_dataset.drop(['Period'], axis = 1).fillna(0)
    exog = sm.tools.tools.add_constant(df[i]).fillna(0)
    white_test_results = het_white(pooled_OLS_dataset['residual'], exog)

    # 3A.3 Breusch-Pagan-Test
    breusch_pagan_test_results = het_breuschpagan(pooled_OLS_dataset['residual'], exog)
    durbin_watson_test_results = durbin_watson(pooled_OLS_dataset['residual']) 

    exog = sm.tools.tools.add_constant(df[i])
    endog = df[j]
    model_re = RandomEffects(endog, exog) 
    re_res = model_re.fit() 
    # fixed effects model
    model_fe = PanelOLS(endog, exog, entity_effects = True) 
    fe_res = model_fe.fit() 
    # time effects
    model_te = PanelOLS(endog, exog, time_effects = True)
    te_res =  model_te.fit() 
    # time effects
    model_te_fe = PanelOLS(endog, exog, entity_effects = True, time_effects = True)
    fe_te_res =  model_te_fe.fit() 

    hausman_results1 = hausman(fe_res, re_res) 
    hausman_results2 = hausman(te_res, re_res) 
    hausman_results3 = hausman(fe_te_res, re_res)
    hausman_results4 = hausman(te_res, fe_res)
    hausman_results5 = hausman(fe_te_res, fe_res)
    hausman_results6 = hausman(fe_te_res, te_res)

    results = results.append({'Independent Variable' : i, 'Dependent' : j, 'White Test P-Value' : white_test_results[1], 'Breusch Pagan Test P-Value' : breusch_pagan_test_results[1],
                              'Durbin Watson Test P-Value' : durbin_watson_test_results, 'Random Effect P-Values' : re_res.pvalues[1], 'Const R' : re_res.params[0], 'I Var R' : re_res.params[1], 
                              'Fixed Effect P-Values' : fe_res.pvalues[1], 'Const FE' : fe_res.params[0], 'I Var FE' : fe_res.params[1], 'Time Effect P-Values' : te_res.pvalues[1], 
                              'Const FT' : te_res.params[0], 'I Var FT' : te_res.params[1], 'Entity and Time P-Values' : fe_te_res.pvalues[1], 'Const FA' : fe_te_res.params[0], 'I Var FA' : fe_te_res.params[1],
                              'Hausman Entity vs Random' : hausman_results1[2], 'Hausman Time vs Random' : hausman_results2[2],
                              'Hausman Entity and Time vs Random' : hausman_results3[2], 'Hausman Time vs Entity' : hausman_results4[2],
                              'Hausman Entity and Time vs Entity' : hausman_results5[2], 'Hausman Entity and Time vs Time' : hausman_results6[2]}, ignore_index = True)

# %%
results.head()
# Out:
#   Independent Variable  ... Hausman Entity and Time vs Time
# 0               PSEGDP  ...                        0.913563
# 1               PSEGDP  ...                        0.043721
# 2               PSEGDP  ...                        0.153211
# 3              Old_Age  ...                        0.998399
# 4              Old_Age  ...                        0.981053
#
# [5 rows x 23 columns]
